# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import matplotlib.pyplot as plt


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
class Board:
    """
    should contain an 8 x 8 grid
    """
    def __init__(self):
        # create an all black board to start
        self.chessboard = np.zeros((8,8,3))
        # now need to color alternating ones white (aka (1,1,1))
        
        # HOW TO IDENTIFY COLORS????
        
    def add_red(self, row, col):
        # color cell at given coordinates red
        pass
    
    def add_blue(self, row, col):
        # color cell at given coordinates blue
        pass
    
    def render(self):
        """
        use plt's imshow method
        """
        pass
    
    def is_under_attack(self):
        """
        "look at" board and find the blue cell and the red cell
        then determine is red is under attack by blue
        
        if red and blue on same row then True
        if red and blue on same column then True
        if red and blue on same diagonal then True
          - Top Left, Top Right, Bottom Left, Bottom Right
        otherwise return False
        
        """
        pass
    
    def is_black(self, row, col):
        """
        demonstration of finding a cell's color.
        This method is NOT needed for lab.
        It's just an example of coloring a cell at given row,column
        """
        cell_color = self.chessboard[row, col]
        black = (0,0,0)
        
        # to compare numpy arrays must use specific method
        if np.array_equal(cell_color, black):
            return True
        
        # or you can check each channel independently
        
#         if cell_color[0] == 0 and cell_color[1] == 0 and cell_color[2] == 0:
#             return True
        
        return False

# %%
board = Board()
board.is_black(4,5)
# Out:
# True

# %%
grid = np.ones((8,8,3)) # make 4 channels for RGBA

row = 2
column = 5
red_channel = 0
green_channel = 1
blue_channel = 2

grid[row][column][red_channel] = 0 # red
grid[row][column][green_channel] = 0 # green
grid[row][column][blue_channel] = 0 # blue

# %%
result = np.float64(1) + 2
type(result)
# Out:
# numpy.float64

# %%
plt.imshow(grid)

# %%
red_channel_zero_to_one_scale = 245 / 255.0
green_channel_zero_to_one_scale = 93 / 255.0
blue_channel_zero_to_one_scale = 204 / 255.0

dragon_fruit = (red_channel_zero_to_one_scale, green_channel_zero_to_one_scale, blue_channel_zero_to_one_scale)
board.chessboard[2,5] = dragon_fruit
plt.imshow(board.chessboard)
